# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "gpt-oss"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": True
#        "options": {
#            "num_threads": 10
#        }
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull gpt-oss
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling b112e727c6f1: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 55c108d8e936: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS, stream=True)

for line in response.iter_lines():
    if line:
        data = line.decode('utf-8')
        # Each line is a JSON object
        import json
        chunk = json.loads(data)
        # The content is in chunk['message']['content']
        print(chunk['message']['content'], end='', flush=True)
# Out:
# ## Generative AI in Business: A Practical Overview
#
# Generative AI—models that create text, images, code, audio, and more—has moved from research labs to everyday corporate workflows. Below is a “menu” of the most impactful business applications, grouped by functional area, with concrete examples, typical tools, and the key benefits they unlock.
#
# | Function | Core Capability | Typical Use‑Cases | Example Tools | Key Business Value |
# |----------|-----------------|-------------------|---------------|--------------------|
# | **Marketing & Brand** | Text & imagery generation | • Ad copy, social posts, email campaigns<br>• Brand‑consistent imagery and video scripts | GPT‑4, Claude, DALL·E 3, Midjourney, Stable Diffusion, Jasper AI | Faster creative cycles, lower cost per unit of content, 24/7 campaign production |
# | **Product Design & R&D** | 3‑D modeling, code synthesis, data augmentation | • Rapid prototyping (CAD, architecture, fashion)<br>• Simulated datasets for ML training<br>• Auto‑generating test cases | GitHub Copilot, Diffusion‑based 3D generation (DreamStudio), OpenAI Codex, DeepMind's AlphaFold | Shorter go‑to‑market, higher design fidelity, data‑rich experimentation |
# | **Customer Experience & Support** | Conversational agents, dynamic FAQs, sentiment analysis | • 24/7 chatbots that write human‑like replies<br>• Voice assistants that generate contextual answers<br>• Real‑time translation & summarization | ChatGPT, Google Gemini, Microsoft Azure OpenAI, IBM Watson Assistant | Improved NPS, reduced CSAT wait times, scalable support |
# | **Finance & Accounting** | Natural‑language reporting, audit trail generation | • Auto‑draft financial statements & footnotes<br>• Real‑time risk alerts with explanatory text<br>• Automated invoice‑to‑account reconciliation | GPT‑4, Jasper Finance, KPMG Clara | Faster reporting, higher audit accuracy, risk mitigation |
# | **Human Resources & Talent** | Content & communication generation | • Personalized onboarding documents<br>• Interview‑style Q&A creation<br>• Resume screening summaries | OpenAI GPT, Lobe, Pymetrics, HireVue | Higher engagement, unbiased screening, reduced hiring time |
# | **Legal & Compliance** | Document drafting & review, policy generation | • Drafting NDAs, contracts, privacy policies<br>• Real‑time compliance monitoring | LawGeex, Evisort, Kira Systems, Microsoft Copilot for Office | Lower legal cost, faster turnaround, consistent policy adherence |
# | **Operations & Supply Chain** | Forecasting models, scenario generation | • Demand‑forecast narratives<br>• What‑if simulation of disruptions<br>• Optimized routing descriptions | IBM Planning Analytics, SAP GenAI, Oracle Autonomous Database | Reduced inventory costs, proactive risk management |
# | **Sales & Enablement** | Proposal & pitch generation, personalized demos | • Auto‑generate sales decks based on data<br>• Create tailored demo scripts<br>• Simulate objection handling dialogues | Slidebean, Gong, SalesLoft, HubSpot AI | Higher win rates, shorter sales cycles, consistent messaging |
# | **IT & DevOps** | Code synthesis, auto‑documentation, vulnerability patching | • Generate boilerplate code, APIs, unit tests<br>• Explain system logs & error reports<br>• Auto‑fix known security bugs | GitHub Copilot, OpenAI Codex, Snyk, DeepCode | Faster release cadence, reduced defect density |
# | **Research & Development** | Hypothesis generation, literature review | • Summarize research papers<br>• Suggest experimental designs<br>• Generate synthetic biological sequences | PubMed GPT, Semantic Scholar, BioGPT, AlphaFold | Accelerated discovery, reduced time to publication |
#
# ---
#
# ## Deep Dive into Representative Use‑Cases
#
# ### 1. Marketing Automation
#
# **Scenario:** A consumer goods company wants to produce 100 unique social‑media posts per day across 5 platforms, each with brand‑specific tone.
#
# **Solution:**
# - **Tool:** GPT‑4 or Claude for text, DALL·E 3 for images.
# - **Process:** Input a high‑level brief (“product launch, eco‑friendly, playful tone”), let the model produce copy + image prompt.
# - **Output:** Schedule via Buffer or Hootsuite.
# - **Result:** 5x content production speed, $10k/month saved on agency spend, content freshness measured by engagement uplift.
#
# ### 2. AI‑Driven Code Generation in Finance
#
# **Scenario:** The treasury team needs to automate complex Excel VBA macros for risk calculations.
#
# **Solution:**
# - **Tool:** GitHub Copilot + OpenAI Codex.
# - **Process:** Provide comments describing logic, let the model write the macro, run unit tests.
# - **Result:** 70% reduction in manual coding time, fewer human errors, compliance audit logs captured automatically.
#
# ### 3. Personalized Legal Document Drafting
#
# **Scenario:** A startup’s legal team drafts NDAs for 200 contractors each month.
#
# **Solution:**
# - **Tool:** LawGeex or a custom GPT‑4 legal model fine‑tuned on the company’s templates.
# - **Process:** Input contractor details + jurisdiction, get a draft with highlighted clauses.
# - **Result:** 90% reduction in drafting time, consistent clause coverage, lower counsel cost.
#
# ### 4. Dynamic Forecast Narratives for Supply Chain
#
# **Scenario:** Demand planners need to explain forecast changes to the sales team in a narrative form.
#
# **Solution:**
# - **Tool:** OpenAI GPT integrated into the forecasting system.
# - **Process:** Feed the numeric forecast plus external data (weather, events) to the model.
# - **Result:** Automatic email generation: “Due to the upcoming sports event, demand for product X will increase by 15%…”. Saves planners 2 hours/day.
#
# ### 5. AI‑Powered Sales Pitch Automation
#
# **Scenario:** Account managers need to prepare bespoke proposals for each prospect.
#
# **Solution:**
# - **Tool:** Slidebean + GPT‑4.
# - **Process:** Pull CRM data, feed into the model to generate slide content and speaker notes.
# - **Result:** 60% faster deck creation, consistent messaging, higher win probability.
#
# ---
#
# ## Why These Use‑Cases Deliver Value
#
# | Benefit | How Generative AI Achieves It |
# |---------|------------------------------|
# | **Speed** | Models produce content instantly vs hours of human drafting. |
# | **Scalability** | One AI can serve thousands of users, eliminating linear cost growth. |
# | **Consistency** | AI enforces brand tone, legal compliance, and best‑practice guidelines. |
# | **Personalization** | On‑demand customization based on data inputs. |
# | **Cost Reduction** | Fewer staff hours, lower agency or contractor spend. |
# | **Innovation** | Rapid prototyping, creative exploration beyond human imagination. |
#
# ---
#
# ## Implementation Tips
#
# 1. **Start Small** – Pilot a single workflow (e.g., auto‑drafting email subject lines) to prove ROI before scaling.
# 2. **Data Governance** – Ensure source data privacy and model output auditing; use fine‑tuning on company‑specific corpora to control bias.
# 3. **Human‑in‑the‑Loop** – Combine AI outputs with expert review; use “preview” modes where humans edit before publishing.
# 4. **Performance Metrics** – Track KPIs like cycle time, cost per unit, error rate, and customer satisfaction.
# 5. **Ethical Guardrails** – Implement content filters, bias mitigation, and transparency logs.
#
# ---
#
# ## Bottom‑Line Takeaway
#
# Generative AI transforms **how** business units create, communicate, and innovate. From slashing content creation time in marketing to automatically drafting compliance‑ready contracts, the technology moves organizations from “manual, costly, slow” to “automatic, consistent, agile”. By strategically aligning AI tools with business pain points, companies can achieve measurable efficiency gains and unlock new revenue streams—often with the same talent and infrastructure they already possess.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

for chunk in ollama.chat(model=MODEL, messages=messages, stream=True):
    print(chunk['message']['content'], end='', flush=True)
# Out:
# ## Generative AI in Business: A Landscape of Practical Applications
#
# Generative AI—systems that can create text, images, audio, video, code, or even 3D models—has moved beyond research labs into everyday enterprise workflows. Its “creativity” is now a measurable business asset that can shorten time‑to‑market, cut costs, and unlock new revenue streams. Below is a non‑exhaustive map of the most impactful use cases, organized by business function and accompanied by concrete examples.
#
# | Business Function | Use‑Case | What It Generates | Value Drivers | Typical Challenges |
# |-------------------|----------|-------------------|---------------|--------------------|
# | **Marketing & Sales** | Content generation | Blog posts, ad copy, social media snippets | Scale content production, maintain brand voice | Ensuring factual accuracy, avoiding repetitive phrasing |
# | | Personalization engine | Tailored product recommendations, dynamic emails | Higher conversion, improved customer experience | Data privacy, model bias |
# | | Creative asset design | Banner ads, landing‑page mock‑ups, explainer videos | Rapid prototyping, on‑demand visual assets | Brand consistency, design “bloat” |
# | **Product Development** | Ideation & design | 3D models, UI mock‑ups, user‑story drafts | Accelerate MVPs, explore design variants | Intellectual property, quality control |
# | | Code synthesis | Boilerplate, API wrappers, even full modules | Shorten development cycles, reduce repetitive coding | Maintainability, security vetting |
# | **Customer Service** | Virtual assistants | FAQ responses, ticket triage, policy summaries | 24/7 coverage, lower agent load | Handling edge cases, escalation routing |
# | | Sentiment & intent analysis | Emotion tagging, urgency scoring | Proactive support, priority routing | Nuanced language, sarcasm detection |
# | **Finance & Operations** | Report drafting | Quarterly reports, compliance filings, audit narratives | Speed up regulatory reporting | Accuracy, regulatory compliance |
# | | Forecasting & scenario simulation | Synthetic financial data, market scenarios | Risk assessment, strategic planning | Model validity, data leakage |
# | **Human Resources** | Recruitment & onboarding | Interview scripts, résumé parsing, training modules | Reduce bias, improve candidate experience | Ethical concerns, data privacy |
# | | Knowledge base generation | Internal wikis, policy documents, FAQ | Faster onboarding, knowledge retention | Consistency, version control |
# | **Manufacturing & Logistics** | Demand forecasting | Synthetic sales data, supply‑chain simulations | Optimize inventory, reduce waste | Data sparsity, external shocks |
# | | Maintenance planning | Predictive maintenance schedules, failure mode simulations | Increase uptime, cut repair costs | Sensor data quality, model drift |
#
# ---
#
# ### 1. Marketing & Sales
#
# #### Text & Copy
# - **Dynamic Ad Copy**: Using large language models (LLMs) to produce thousands of unique headlines and descriptions that adapt to user demographics and browsing history.
# - **Email Personalization**: Generating subject lines and body copy that reference recent customer interactions, boosting open and click‑through rates.
#
# #### Visual & Multimedia
# - **Brand‑Consistent Imagery**: AI image generators produce product photos, lifestyle shots, and infographics that match brand guidelines without hiring photographers.
# - **Explainer Videos**: Prompting text‑to‑video models to create short product demos or tutorial clips, reducing video‑production overhead.
#
# ### 2. Product Development
#
# #### Design Prototyping
# - **UI/UX Mock‑ups**: Prompt‑based design tools (e.g., Midjourney, Figma’s generative plugins) can turn a feature brief into multiple wireframe variants in minutes.
# - **3D Asset Generation**: Generative 3D models accelerate game development, AR/VR applications, and product visualizations.
#
# #### Code Generation
# - **Automated Boilerplate**: Models like GitHub Copilot or OpenAI’s Codex can write API wrappers, CRUD operations, or test cases from a specification, cutting developer onboarding time.
# - **Full‑Stack Scripts**: Some platforms can spin up microservices or serverless functions from a high‑level description, enabling rapid prototyping.
#
# ### 3. Customer Service
#
# #### Conversational AI
# - **Chatbots & Voice Assistants**: Generative models power realistic dialogue, handling common queries, and even summarizing policy documents for end users.
# - **Escalation Prediction**: AI analyzes chat sentiment and tone to flag high‑risk tickets that should be routed to a human agent.
#
# #### Knowledge Base
# - **Automated FAQ Updates**: By scanning new product releases or policy changes, AI can rewrite or add FAQ entries, keeping the help center fresh.
#
# ### 4. Finance & Operations
#
# #### Regulatory Compliance
# - **Automated Report Drafting**: Generative models ingest raw financial data and output audit narratives, compliance forms, or internal financial statements in a fraction of the manual effort.
#
# #### Forecasting
# - **Synthetic Data for Scenario Planning**: In environments with limited historical data (e.g., new product lines), AI can generate plausible market‑scenario datasets to feed predictive models, improving robustness.
#
# ### 5. Human Resources
#
# #### Recruitment Automation
# - **Job Description Refinement**: AI can rewrite job posts to eliminate gendered language or to target under‑represented talent pools.
# - **Resume Parsing & Summaries**: Generative models convert diverse résumé formats into structured data, summarizing key achievements for recruiters.
#
# #### Onboarding Content
# - **Dynamic Training Modules**: By ingesting corporate policies and role‑specific processes, AI can produce personalized onboarding journeys for new hires.
#
# ### 6. Manufacturing & Logistics
#
# #### Demand Simulation
# - **Synthetic Sales Histories**: Generate plausible sales curves for new SKUs to help planners evaluate inventory strategies without waiting for real data.
# - **Predictive Maintenance**: AI can simulate machine failure scenarios, allowing maintenance teams to test preventative schedules before deployment.
#
# ---
#
# ## Common Threads Across Applications
#
# | Driver | How Generative AI Helps | Caveat |
# |--------|------------------------|--------|
# | **Speed** | Instant content/code/asset generation | Needs post‑hoc review |
# | **Scale** | Mass‑produce variants (copy, designs, data) | Quality control is critical |
# | **Cost Reduction** | Fewer human hours on repetitive tasks | Initial investment in tooling |
# | **Personalization** | Tailor messages or products at scale | Must guard against bias |
# | **Innovation** | Rapid iteration on ideas (design, features) | Requires human oversight to stay strategic |
#
# ## Implementation Checklist
#
# 1. **Define Clear Objectives** – What business outcome does the generative tool serve? (e.g., 20% faster content production, 15% uplift in CTR)
# 2. **Select the Right Model & Platform** – Proprietary vs. open‑source, on‑prem vs. cloud, compute requirements.
# 3. **Establish Governance** – Data privacy, bias mitigation, audit trails.
# 4. **Human‑in‑the‑Loop** – Set thresholds for when a human must review or approve outputs.
# 5. **Measure & Iterate** – Track KPIs, gather user feedback, fine‑tune models.
#
# ---
#
# ### Looking Ahead
#
# - **Multimodal Fusion**: Combining text, image, and audio generation in a single workflow (e.g., a chatbot that can describe a product image in words).
# - **Domain‑Specific Fine‑Tuning**: As more industry‑specific datasets become available, generative models can produce highly accurate, context‑aware outputs (e.g., legal document drafting).
# - **Regulation‑Friendly AI**: With frameworks like the EU’s AI Act, businesses will need to ensure explainability and auditability of generative outputs.
#
# In short, generative AI is no longer a novelty; it is a practical lever that can accelerate everything from marketing copy to code, from design to compliance. The businesses that integrate it thoughtfully—balancing automation with human insight—will find themselves ahead of the curve.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages,
    stream=True
)

for chunk in response:
    if chunk.choices and chunk.choices[0].delta and chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end='', flush=True)
# Out:
# ### Generative AI in the Business Landscape
# Generative AI—models that can create new text, images, sound, code, and even simulated data—has moved from research curiosity to a practical asset across industries. Below are some of the most compelling, real‑world business applications, grouped by the value they unlock.
#
# | # | Category | Primary Value | Representative Use Cases | Typical Companies / Products |
# |---|----------|----------------|---------------------------|------------------------------|
# | 1 | **Content & Marketing** | Create compelling copy, media, and brand assets at scale. | • Automated blog posts, white‑papers, and email newsletters.<br>• Social‑media post generation with tone‑matching.<br>• Personalized product descriptions for e‑commerce catalogs.<br>• AI‑generated visual assets (illustrations, infographics, short videos). | Jasper, Copy.ai, Adobe Firefly, Canva AI, Canva Design Generator |
# | 2 | **Customer Experience & Support** | Intelligent, context‑aware assistance that reduces friction. | • Conversational chatbots that draft responses, handle complex queries, and upsell products.<br>• Voice assistants that understand intent, summarize long calls, and route tickets.<br>• Real‑time translation of customer messages. | Zendesk Chat GPT, Intercom, Freshchat, LivePerson, Microsoft Dynamics 365 Copilot |
# | 3 | **Product & Service Innovation** | Rapid prototyping, customization, and design iteration. | • AI‑driven UI/UX mockups from spec text.<br>• Custom apparel or home‑decor design on demand.<br>• Generative design in architecture and industrial manufacturing (e.g., shape‑optimized airplane components). | Autodesk Dreamcatcher, NVIDIA Canvas, Nike’s “Creativ3”, Autodesk Generative Design |
# | 4 | **Software Development & Operations** | Accelerate coding, testing, and system management. | • Code generation from natural‑language prompts.<br>• Automated documentation and API examples.<br>• Auto‑generation of unit tests and refactoring suggestions.<br>• Infrastructure‑as‑Code skeletons. | GitHub Copilot, Amazon CodeWhisperer, Azure OpenAI Studio, Microsoft Power Platform + Copilot |
# | 5 | **Information & Synthesis** | Transform unstructured data into actionable insights. | • Summarizing long contracts, legal documents, and compliance reports.<br>• Generating executive‑level briefings from raw meeting transcripts.<br>• Drafting market‑research reports or investment memos. | OpenAI’s ChatGPT for business, Salesforce Einstein, SAP CoPilot, Thomson Reuters Eikon |
# | 6 | **Risk Management & Compliance** | Simulate scenarios, detect patterns, and maintain regulatory compliance. | • Synthetic data for privacy‑preserving risk modeling.<br>• Generating plausible fraud scenario narratives for training.<br>• Auto‑generation of regulatory risk checklists. | Scribe, DataRobot, Riskified, OpenAI for Finance APIs |
# | 7 | **Data Augmentation & Simulation** | Fill data gaps, train ML models, and test systems. | • Creating synthetic customer conversations for training chatbots.<br>• Simulating medical imaging data for radiology training.<br>• Generating synthetic financial time‑series for back‑testing algorithms. | Synopsys, Deep Genomics, Monte Carlo simulators in FinTech, DALL‑E 2 for data diversification |
# | 8 | **Human Resources & Talent** | Efficient hiring, training, and employee engagement. | • AI‑generated interview questions and evaluation scripts.<br>• Training simulations for skill building (e.g., negotiation, crisis response).<br>• Personal learning path creation. | HireVue, Pymetrics, LinkedIn Learning with AI, Google AI HR tools |
# | 9 | **Creative Arts & Media** | Amplify human creativity and streamline production. | • Automated scriptwriting, plot outlines, or dialogue drafting.<br>• Music composition for ads, video games, or streaming services.<br>• AI‑editted video and post‑production elements. | AIVA for music, ScriptAI, Adobe Sensei, Epic Games' MetaHuman Generator |
# |10 | **Business Strategy & Forecasting** | Scenario planning and strategic foresight. | • Generative models that produce multiple market‑trend narratives.<br>• Automated hypothesis generation for AB testing.<br>• Rapid “what‑if” simulation of cost structures. | IBM Watson Decision Platform, OpenAI GPT‑4 for scenario analysis, AlphaSense + AI |
#
# ---
#
# ## How These Applications Deliver Business Value
#
# | Value Driver | Business Impact |
# |--------------|-----------------|
# | **Speed** | From milliseconds of GPT‑4 prompting to days of full‑feature web‑applications, generative AI slashes time‑to‑value. |
# | **Scale** | One model can produce thousands of distinct product descriptions or marketing pieces with minimal human input. |
# | **Personalization** | By conditioning on customer data, AI can generate highly tailored messaging or product variants that appeal to individual segments. |
# | **Cost Efficiency** | Automating content, support, and development reduces labor hours and helps allocate talent to higher‑value tasks. |
# | **Risk Reduction** | Synthetic data and scenario generation mitigate data‑privacy issues and bolster security testing. |
# | **Innovation Acceleration** | Designers and engineers can iterate rapidly; creative professionals generate ideas that would take weeks otherwise. |
#
# ---
#
# ## Real‑World Success Stories
#
# | Company | What They’re Doing | Outcome |
# |---------|-------------------|---------|
# | **Spotify** | AI‑generated song recommendations that learn from real‑time listening behavior. | Increased user engagement metrics and reduced churn. |
# | **Adobe** | Firefly: generative design for assets (logos, images, mockups) that integrate with Adobe Creative Cloud. | Empowered designers to prototype faster; upsold Adobe CC licenses. |
# | **American Express** | GPT‑4‑powered customer service bot for handling 24/7 inquiry tickets. | Cut average handling time by 25%; improved 90‑day retention. |
# | **BMW** | GPT‑based “Generative Design” for lightweight, optimized parts that reduce fuel consumption. | Delivered 15% weight savings on specific components. |
# | **KPMG** | Generative AI for contract review and compliance checklists. | Cut due‑diligence analysis time by 30% for large M&A deals. |
#
# ---
#
# ## Key Considerations When Deploying Generative AI
#
# 1. **Ethics & Bias**
#    - Models can replicate or amplify biases present in training data.
#    – Establish bias‑audit protocols and transparent human‑in‑the‑loop oversight.
#
# 2. **Data Privacy & Security**
#    – For synthetic data, be sure to comply with GDPR/CCPA and internal policy.
#    – Ensure generation pipelines don’t inadvertently leak proprietary information.
#
# 3. **Quality Control**
#    - Human editors or domain experts should validate critical outputs, especially in regulated sectors (finance, healthcare).
#
# 4. **Explainability**
#    - For regulated use cases, add a human‑readable “why” component or a confidence score.
#
# 5. **Model Lifecycle Management**
#    – Continually retrain and monitor for drift; schedule periodic model reviews.
#
# 6. **Cost & Compute**
#    – Generative inference can be expensive; evaluate GPU usage, cloud credits, and potential model distillation.
#
# ---
#
# ## Quick Take‑away
#
# Generative AI is no longer a niche experiment—it’s a versatile business engine that can:
#
# | Domain | What AI Does | Key Result |
# |--------|--------------|------------|
# | **Marketing** | Auto‑writes & localizes copy | Rapid campaign launches |
# | **Support** | AI‑first response & ticket triage | Lower ops cost |
# | **Product Design** | Generates prototypes & custom options | Faster time‑to‑market |
# | **Engineering** | Writes code, docs, tests | Higher developer velocity |
# | **Finance** | Synthesizes data for risk models | Better stress‑testing |
# | **HR** | Creates candidate briefs & training modules | Smarter hiring |
#
# If you’re exploring generative AI, start by identifying a repetitive, data‑heavy process that could benefit from “create‑in‑a‑click” power. Build a small pilot, involve the relevant stakeholders, and iterate. The right use of generative AI can turn an organization from “reactive” to “predictive” in record time.

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling e6a7edc1a4d7: 100% ▕██████████████████▏ 5.2 GB
# pulling c5ad996bda6e: 100% ▕██████████████████▏  556 B
# pulling 6e4c38e1172f: 100% ▕██████████████████▏ 1.1 KB
# pulling ed8474dc73db: 100% ▕██████████████████▏  179 B
# pulling f64cd5418e4b: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, the user is asking for definitions related to LLMs—neural networks, attention mechanisms, and transformers. Let me start by understanding their query properly.
#
# First, they might be new to AI or NLP, trying to grasp the basics before diving into more complex topics. I should make sure my explanations are clear but not too simplistic. They mentioned "core concepts," so maybe they want a foundational understanding without getting bogged down in details.
#
# I need to define each term individually because combining them could be overwhelming. But showing how they connect will help their comprehension. Let me recall the basics of neural networks first. Explain feedforward, layers, weights and biases briefly.
#
# Next, attention mechanisms. People often hear "attention" but don't know what it does exactly. Compare it to human attention if possible, using examples like reading a text where key words stand out. Mention the query-key-value analogy—that should be standard in explanations now.
#
# Then transformers: the whole architecture's role as a neural network with attention at its core. Maybe compare CNNs and RNNs limitations? Transformers rely on self-attention, which allows parallel processing unlike RNNs.
#
# Wait, does the user need me to differentiate from other architectures like RNNs or CNNs? Yes, because without that context, transformers might seem magical rather than an answer to specific problems. Also, mentioning why attention is crucial for handling long-range dependencies in text could help them see the bigger picture.
#
# Are there any pitfalls I should address? For instance, they might wonder where the original "transformer" paper came from and its impact on LLMs. Or maybe how self-attention works computationally—keep it high-level but mention vector spaces and multiplicative interactions for contrast with feedforward layers.
#
# Should I clarify that not all transformers are used in NLP? Like the vision transformer, but the user is specifically interested in LLMs which focus more on the text transformer aspect. Maybe stick to relevant context unless they ask broader questions.
#
# Also, note their potential need: understanding how different concepts work under the hood might satisfy deeper curiosity about model internals rather than just surface-level applications. They're not looking for quick demos but a theoretical explanation that ties everything together.
#
# Make sure each definition leads logically into explaining how it relates to transformers and ultimately to LLMs performance. Emphasize compositional meaning with positional encodings, parallel processing advantages over RNNs, handling long-range dependencies via attention—all key points in why transformers are suitable for large-scale language models.
# </think>
# Okay, let's break down these core concepts that underpin Large Language Models (LLMs).
#
# While LLMs specifically refer to the type and scale of model we're dealing with now, their operation fundamentally relies on *neural networks*, particularly *transformer* architectures *equipped with self-attention mechanisms*. Understanding each part is crucial.
#
# ---
#
# **1. Neural Network**
#
# **Definition:** A neural network is a computing system inspired by biological neural systems made of units called "artificial neurons" and connections between them, analogous to the human brain. It consists of multiple interconnected layers (linear transformations followed by non-linear activation functions) designed to perform calculations on digital data.
#
# Key Components:
#
# *   **Neurons:** Basic computation units that receive signals through connections (synapses), process them based on its own weighted inputs and bias, and then sends an output signal forward if the summed input meets a certain threshold. In ML models, this translates to:
#     *   A sum of `(input_value) * weight` values plus a `bias`.
#     *   Application of an **activation function** (like ReLU, tanh, sigmoid), which introduces non-linearity – essential for learning complex patterns.
# *   **Layers:** Collections of neurons working together. Common types include:
#     *   **Dense/Feed-Forward Layer:** Each neuron connects to every neuron in the next layer. This is basic linear algebra followed by an activation function (e.g., `W.x + b` then ReLU).
#     *   **Convolutional Layer (CNN):** Specialized for grids of data (like images). It applies many small filters across different spatial positions, capturing local patterns.
#     *   **Recurrent Layer (RNN variant):** Designed to process sequential or time-series data where information persists. Each "step" treats an input token separately and considers its own previous state output sequentially (`state_old = RNN(input_token)` followed by a feed-forward part). This allows processing one element at a time, capturing temporal dependencies.
# *   **Weights & Biases:** Parameters learned from the training data (adjustable knobs) that define how much each connection influences the computation. They determine what patterns the model learns. Adjusting them is the learning process.
#
# How it relates to LLMs: An LLM is a specific type of neural network, large by modern standards, comprising hundreds or thousands of layers designed specifically for processing sequences of tokens (the building blocks of text) and learning deep language patterns. The most successful LLMs use *transformer* architecture as their core structure.
#
# ---
#
# **2. Attention Mechanism**
#
# **Definition:** In machine translation, visual recognition tasks, and large language models like GPT-3/4/Journey, an attention mechanism is a set of learned functions that allow a model to focus selectively on different parts of its input depending on what it needs to compute at each step.
#
# Think of **attention** as learning *where* in the input most relevant information for generating the next part of an output appears. It's not just about looking "this way" or "that way"; models learn where those directions point so they can locate important parts efficiently and effectively over large inputs/outputs.
#
# Mechanism:
#
# Consider translating a sentence: "The animal came to a farm."
# If we're translating each word (the current *token*) one by one, an attention model doesn't just use the fixed context of words before it. Instead:
#
# 1.  For generating "oink", it might pay significant attention to "animal".
# 2.  For generating "farm's" in English and "fatture de ferme au bétail" (translation for "farm") or similar French phrase, it would look more at the word "farm".
#
# The *self-attention* mechanism used in transformers specifically handles sequences like text inputs themselves – attending to different tokens within its own input sequence.
#
# How it relates to LLMs: Self-attention is crucial for LLMs. Their massive scale allows them to learn effective attention mechanisms, enabling understanding and generation that relies heavily on long-range context, relationships between distant words in a sentence, coherence across paragraphs, and subtle world knowledge embedded in language patterns. Without self-attention, models like those based solely on RNNs struggle inefficiently with very long texts (e.g., finding connections far downstream).
#
# ---
#
# **3. Transformer**
#
# **Definition:** Transformer is an architectural family for neural networks designed to process data sequentially by learning to explicitly incorporate attention into their internal design mechanisms at every step. It "specializes" in modeling the meaning of sequences through self-attention, avoiding the inherent complexities and dependencies (like long-range context) that other sequence-based architectures like RNNs implicitly struggle with.
#
# Key Feature: **Self-Attention Mechanism** embedded directly within each layer (multiple layers).
#
# Architecture Components:
#
# *   **Input Embedding:** Converts raw tokens (e.g., words or subwords) into dense vectors of floating point numbers in a vector space. This captures semantic information about the input token.
# *   **Positional Encoding:** Since transformer networks process inputs all at once, they lose inherent "sequential order" information. Positional encoding adds this by attaching learnable embeddings to each position in the sequence that correlate with its index (start/end/middle). These are then added element-wise to the embedding vector before processing.
# *   **Self-Attention Layer:** This is the core innovation. Each token's input representation (`x`) is used as a *query*. The same `x` plus different contexts are used as *keys* and values related to each other. Calculate attention scores (how "connected" or relevant query is to key), then use these scores multiplicatively to combine ("value") representations, effectively computing weighted sums based on the relevance established by self-attention.
#
# *   Then a **Feed Forward Layer** (`W.x + b`) might be applied for nonlinear processing.
# *   Each attention layer (often preceded/preceded by *Layer Normalization* adding internal structure resilience and post-processing normalization) is followed by *Add & Norm* operations combining the input of that layer with its output, then applying another LayerNorm to stabilize further steps.
#
# The Transformer architecture thus solves two main problems:
#
# 1.  **Sequence Processing Bottleneck:** RNNs process one token at a time sequentially, making training very slow for long texts. Transformers use self-attention across all tokens simultaneously, enabling much faster training.
# 2.  **Long-Range Dependencies Problem:** Standard CNN/RNNs often have difficulty capturing relationships between distant words in a sentence (like the start of a topic being repeated later). Self-Attention allows every token to directly interact with every other token via learned representations, regardless of distance.
#
# How it relates to LLMs: A Large Language Model is likely implemented using the transformer architecture. These models often use *encoder-only* transformers where input tokens pass through many layers (with self-attention) and influence each other's representation at each step before being outputted as context for generation or reasoning tasks. This learned, large-scale model allows it to capture complex language structures at multiple levels of abstraction and scale implicitly knowledge about the world.
#
# ---
#
# In summary:
#
# *   A **neural network** is a core machine learning structure with adjustable parameters (weights/biases) in layers.
# *   An **attention mechanism**, especially self-attention, solves the problem of tracking context dependencies by letting each position "attend" to relevant parts across the entire sequence. It's about *where* to look for information.
# *   A **transformer** is a specialized neural network architecture that uses multiple self-attention layers (often alongside feed forward layers and normalization) at every processing step, allowing parallel computation on sequences and explicit handling of long-range dependencies.
#
# Together, these building blocks form the foundation upon which LLMs like GPT-3 / ChatGPT were built.

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %%
import ollama
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# udemy = Website(www.udemy.com);
# print(udemy.title)
# print(udemy.text)

# %%
# Let's try one out. Change the website and add print statements to follow along.

ed = Website("https://cloud9computinggroup.com")
print(ed.title)
print(ed.text)
# Out:
# Cloud 9 Computing Group - Enterprise IT Services and Cloud Migration for Small Business
# top of page
# Service Status
# Live Support
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# More
# Use tab to navigate through the menu items.
# We believe
# Standardization
# brings
# focus to Process
# Optimization
# which enables businesses to
# scale
# EXISTING CUSTOMER SUPPORT
# INQUIRE ABOUT OUR SERVICES
# What is Hybrid Cloud?
# We are a
# Managed Service Provider
# with Process and Operations Strategy in Mind
# CLOUD SERVICES
# Optimize application usability and monitor performance with scalable solutions tailored to your needs. We help you enhance uptime, boost efficiency, track employee productivity, and potentially reduce costs, ensuring you only invest in the managed IT services that benefit you most.
# NETWORK SECURITY
# We utilize the same technology as leading Incident Response Firms. Our network security stack aligns with insurer requirements for cybersecurity, aiding in passing SOC and other compliance assessments. Our tools and SOC detect intrusions and help prevent unauthorized access to your systems.
# IT SUPPORT
# Simplify your operations with our comprehensive solutions, including proven processes, ticketing portals, policy templates, experienced helpdesk staff, and shared documentation—all from a single source. We also ensure that your incident response plans align with your business objectives.
# Key Benefits of Our Approach
# SIMPLIFIED TECHNOLOGY, 24/7 ACCESSIBILITY
# Host all of your company’s software, data, and tools in proven environments, making data accessible and secure wherever and whenever you need it.
# INCREASED EFFICIENCY
# Optimize your business’s efficiency by reducing downtime and technical risks by using best in class security tools and practices, redundant systems, and backup recovery tools that meet your objectives.  Use metrics collected on workstations to assess work from home network quality and user productivity.
# INTEGRATED SOLUTIONS
# After examining your biggest pain points, we custom tailor ticketing portals to get personnel results as quickly as possible by asking the right questions at the time a ticket is submitted.
# ​
# We constantly review and refine our processes along with your organization
# CONTROLLABLE MONTHLY COSTS
# Standardizing your IT means standardized pricing, based on the options that fit your company.
# Our pricing model is based on number of users, servers, email accounts, and what level of backup recovery you want available.
# ZERO DOWN-TIME OPTIONS
# If a computer or device quits, your team can continue working from another device without missing a beat.
# We also have specialized server offerings that can withstand catastrophic failure.
# SECURITY MATURE
# Our Security Solutions engage experienced Digital Forensics and Incident Response (DFIR) firms on your behalf, so you can rest assured you'll have best-in-class security and detection that meets compliance requirements and Cyber Liability Audits
# SEE HOW OUR STRATEGIC IT SOLUTIONS CAN BENEFIT YOUR ORGANIZATION
# LEARN MORE
# Key Benefits
# Why We're Different
# Operations Focused Strategic Solutions vs Reactive Approach
# STRATEGIC SOLUTIONS
# TRADITIONAL REACTIVE APPROACH
# Aware of YOUR business goals. Putting roadmaps for operations and technology together.
# Focus on just running the computers and network.
# Constantly refining processes from IT Support, Employees, and Customer feedback
# No Centralized notes for Technicians to follow for the repeated issues and processes
# Established Technology Policies and Employee Security Training out of the box
# Staff has to guess on policies for themselves or their departments
# Use Employee Engagement Metrics to find out if there are better process your team could be doing.  Learn from your own rock stars.
# No Structured Plans for Offboarded Employees, Hardware Budget Reviews, and upcoming projects.  Things only happen as they are needed.
# Rely only on built-in security products that have multiple places to log into for identity validation and can be difficult to setup on mobile devices
# Use Scalable Security Products that can grow with your business across multiple platforms
# Customized Customer Portal with common questions and solutions catered to your staff
# One Size Fits All Ticketing Systems where you can "just email"
# FIND OUT IF YOUR
# IT SUPPORT
# IS
# STRATEGICALLY FOCUSED
# ON
# YOUR BUSINESS
# START NOW
# Why We're Different
# Who We Help
# Custom strategic solutions tailored for your industry
# We provide best practice customized solutions fit to tackle your business's unique needs and concerns
# CONSTRUCTION
# Boost your team's speed and efficiency by making essential files—such as plans, schedules, and project management tools—accessible from anywhere, on any device. Whether you're a specialty contractor or an architecture and engineering firm, we understand your daily tools and deploy them securely and efficiently.
# MANUFACTURING
# With the rise of CIS Frameworks translating into NIST 800-171 compliance, it's crucial to secure manufacturing facilities that often use older machinery. We employ network segmentation, auditing, and innovative solutions to maintain security and functionality.
# ​
# FINANCIAL / LEGAL
# Protect your firm's
# and
# your client's private information by centralizing security, access, and backups where needed. Whether you're in the demanding fast-paced nature of the Legal, Finance or Accounting services.​ We understand SOC Audits, Security Frameworks, Archival Regulations and Compliance.
# BUILD YOUR CUSTOMIZED STRATEGIC PLAN
# GET STARTED
# Who We Help
# What It Costs
# How we work with your budget and team
# At Cloud 9 Computing Group, we offer transparent and flexible pricing structures tailored to your business’s specific needs. Our pricing model is designed to accommodate the unique requirements of your company, factoring in the number of employees, servers, and email accounts. All while ensuring you receive the highest quality of managed IT services and cloud solutions.
# Our solutions are catered to you based on your need.
# Get Your Quote
# What It Costs
# Brands Who Trust Us
# Cloud 9 offers solutions that are right sized for our business – cost effective and yet cutting edge. They have helped us with everything from computer purchases, installs and management, to entire IT infrastructure changes, VOIP phone system implementation, state of the art wireless (WiFi) technology, and cloud servers for software and documents.
# Cloud 9 does it all and they are the best IT partner you could have!
# Pam Russell, Director of Finance and Administration,
# La-Z-Boy Furniture Galleries Orlando
# Our Tech Partners
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# 917 RINEHART RD, SUITE 2027, LAKE MARY, FL 32746
# 877.454.1649
# Refreshed in ©2020 All Rights Reserved.
# Cloud
# bottom of page

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(ed))
# Out:
# You are looking at a website titled Cloud 9 Computing Group - Enterprise IT Services and Cloud Migration for Small Business
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# top of page
# Service Status
# Live Support
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# More
# Use tab to navigate through the menu items.
# We believe
# Standardization
# brings
# focus to Process
# Optimization
# which enables businesses to
# scale
# EXISTING CUSTOMER SUPPORT
# INQUIRE ABOUT OUR SERVICES
# What is Hybrid Cloud?
# We are a
# Managed Service Provider
# with Process and Operations Strategy in Mind
# CLOUD SERVICES
# Optimize application usability and monitor performance with scalable solutions tailored to your needs. We help you enhance uptime, boost efficiency, track employee productivity, and potentially reduce costs, ensuring you only invest in the managed IT services that benefit you most.
# NETWORK SECURITY
# We utilize the same technology as leading Incident Response Firms. Our network security stack aligns with insurer requirements for cybersecurity, aiding in passing SOC and other compliance assessments. Our tools and SOC detect intrusions and help prevent unauthorized access to your systems.
# IT SUPPORT
# Simplify your operations with our comprehensive solutions, including proven processes, ticketing portals, policy templates, experienced helpdesk staff, and shared documentation—all from a single source. We also ensure that your incident response plans align with your business objectives.
# Key Benefits of Our Approach
# SIMPLIFIED TECHNOLOGY, 24/7 ACCESSIBILITY
# Host all of your company’s software, data, and tools in proven environments, making data accessible and secure wherever and whenever you need it.
# INCREASED EFFICIENCY
# Optimize your business’s efficiency by reducing downtime and technical risks by using best in class security tools and practices, redundant systems, and backup recovery tools that meet your objectives.  Use metrics collected on workstations to assess work from home network quality and user productivity.
# INTEGRATED SOLUTIONS
# After examining your biggest pain points, we custom tailor ticketing portals to get personnel results as quickly as possible by asking the right questions at the time a ticket is submitted.
# ​
# We constantly review and refine our processes along with your organization
# CONTROLLABLE MONTHLY COSTS
# Standardizing your IT means standardized pricing, based on the options that fit your company.
# Our pricing model is based on number of users, servers, email accounts, and what level of backup recovery you want available.
# ZERO DOWN-TIME OPTIONS
# If a computer or device quits, your team can continue working from another device without missing a beat.
# We also have specialized server offerings that can withstand catastrophic failure.
# SECURITY MATURE
# Our Security Solutions engage experienced Digital Forensics and Incident Response (DFIR) firms on your behalf, so you can rest assured you'll have best-in-class security and detection that meets compliance requirements and Cyber Liability Audits
# SEE HOW OUR STRATEGIC IT SOLUTIONS CAN BENEFIT YOUR ORGANIZATION
# LEARN MORE
# Key Benefits
# Why We're Different
# Operations Focused Strategic Solutions vs Reactive Approach
# STRATEGIC SOLUTIONS
# TRADITIONAL REACTIVE APPROACH
# Aware of YOUR business goals. Putting roadmaps for operations and technology together.
# Focus on just running the computers and network.
# Constantly refining processes from IT Support, Employees, and Customer feedback
# No Centralized notes for Technicians to follow for the repeated issues and processes
# Established Technology Policies and Employee Security Training out of the box
# Staff has to guess on policies for themselves or their departments
# Use Employee Engagement Metrics to find out if there are better process your team could be doing.  Learn from your own rock stars.
# No Structured Plans for Offboarded Employees, Hardware Budget Reviews, and upcoming projects.  Things only happen as they are needed.
# Rely only on built-in security products that have multiple places to log into for identity validation and can be difficult to setup on mobile devices
# Use Scalable Security Products that can grow with your business across multiple platforms
# Customized Customer Portal with common questions and solutions catered to your staff
# One Size Fits All Ticketing Systems where you can "just email"
# FIND OUT IF YOUR
# IT SUPPORT
# IS
# STRATEGICALLY FOCUSED
# ON
# YOUR BUSINESS
# START NOW
# Why We're Different
# Who We Help
# Custom strategic solutions tailored for your industry
# We provide best practice customized solutions fit to tackle your business's unique needs and concerns
# CONSTRUCTION
# Boost your team's speed and efficiency by making essential files—such as plans, schedules, and project management tools—accessible from anywhere, on any device. Whether you're a specialty contractor or an architecture and engineering firm, we understand your daily tools and deploy them securely and efficiently.
# MANUFACTURING
# With the rise of CIS Frameworks translating into NIST 800-171 compliance, it's crucial to secure manufacturing facilities that often use older machinery. We employ network segmentation, auditing, and innovative solutions to maintain security and functionality.
# ​
# FINANCIAL / LEGAL
# Protect your firm's
# and
# your client's private information by centralizing security, access, and backups where needed. Whether you're in the demanding fast-paced nature of the Legal, Finance or Accounting services.​ We understand SOC Audits, Security Frameworks, Archival Regulations and Compliance.
# BUILD YOUR CUSTOMIZED STRATEGIC PLAN
# GET STARTED
# Who We Help
# What It Costs
# How we work with your budget and team
# At Cloud 9 Computing Group, we offer transparent and flexible pricing structures tailored to your business’s specific needs. Our pricing model is designed to accommodate the unique requirements of your company, factoring in the number of employees, servers, and email accounts. All while ensuring you receive the highest quality of managed IT services and cloud solutions.
# Our solutions are catered to you based on your need.
# Get Your Quote
# What It Costs
# Brands Who Trust Us
# Cloud 9 offers solutions that are right sized for our business – cost effective and yet cutting edge. They have helped us with everything from computer purchases, installs and management, to entire IT infrastructure changes, VOIP phone system implementation, state of the art wireless (WiFi) technology, and cloud servers for software and documents.
# Cloud 9 does it all and they are the best IT partner you could have!
# Pam Russell, Director of Finance and Administration,
# La-Z-Boy Furniture Galleries Orlando
# Our Tech Partners
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# 917 RINEHART RD, SUITE 2027, LAKE MARY, FL 32746
# 877.454.1649
# Refreshed in ©2020 All Rights Reserved.
# Cloud
# bottom of page

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': 'You are looking at a website titled Cloud 9 Computing Group - Enterprise IT Services and Cloud Migration for Small Business\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\ntop of page\nService Status\nLive Support\nSERVICES\nKEY BENEFITS\nWHY WE\'RE DIFFERENT\nWHO WE HELP\nWHAT IT COSTS\nNEWS\nMore\nUse tab to navigate through the menu items.\nWe believe\nStandardization\nbrings\nfocus to Process\nOptimization\nwhich enables businesses to\nscale\nEXISTING CUSTOMER SUPPORT\nINQUIRE ABOUT OUR SERVICES\nWhat is Hybrid Cloud?\nWe are a\nManaged Service Provider\nwith Process and Operations Strategy in Mind\nCLOUD SERVICES\nOptimize application usability and monitor performance with scalable solutions tailored to your needs. We help you enhance uptime, boost efficiency, track employee productivity, and potentially reduce costs, ensuring you only invest in the managed IT services that benefit you most.\nNETWORK SECURITY\nWe utilize the same technology as leading Incident Response Firms. Our network security stack aligns with insurer requirements for cybersecurity, aiding in passing SOC and other compliance assessments. Our tools and SOC detect intrusions and help prevent unauthorized access to your systems.\nIT SUPPORT\nSimplify your operations with our comprehensive solutions, including proven processes, ticketing portals, policy templates, experienced helpdesk staff, and shared documentation—all from a single source. We also ensure that your incident response plans align with your business objectives.\nKey Benefits of Our Approach\nSIMPLIFIED TECHNOLOGY, 24/7 ACCESSIBILITY\nHost all of your company’s software, data, and tools in proven environments, making data accessible and secure wherever and whenever you need it.\nINCREASED EFFICIENCY\nOptimize your business’s efficiency by reducing downtime and technical risks by using best in class security tools and practices, redundant systems, and backup recovery tools that meet your objectives.\xa0 Use metrics collected on workstations to assess work from home network quality and user productivity.\nINTEGRATED SOLUTIONS\nAfter examining your biggest pain points, we custom tailor ticketing portals to get personnel results as quickly as possible by asking the right questions at the time a ticket is submitted.\n\u200b\nWe constantly review and refine our processes along with your organization\nCONTROLLABLE MONTHLY COSTS\nStandardizing your IT means standardized pricing, based on the options that fit your company.\nOur pricing model is based on number of users, servers, email accounts, and what level of backup recovery you want available.\nZERO DOWN-TIME OPTIONS\nIf a computer or device quits, your team can continue working from another device without missing a beat.\nWe also have specialized server offerings that can withstand catastrophic failure.\nSECURITY MATURE\nOur Security Solutions engage experienced Digital Forensics and Incident Response (DFIR) firms on your behalf, so you can rest assured you\'ll have best-in-class security and detection that meets compliance requirements and Cyber Liability Audits\nSEE HOW OUR STRATEGIC IT SOLUTIONS CAN BENEFIT YOUR ORGANIZATION\nLEARN MORE\nKey Benefits\nWhy We\'re Different\nOperations Focused Strategic Solutions vs Reactive Approach\nSTRATEGIC SOLUTIONS\nTRADITIONAL REACTIVE APPROACH\nAware of YOUR business goals. Putting roadmaps for operations and technology together.\nFocus on just running the computers and network.\nConstantly refining processes from IT Support, Employees, and Customer feedback\nNo Centralized notes for Technicians to follow for the repeated issues and processes\nEstablished Technology Policies and Employee Security Training out of the box\nStaff has to guess on policies for themselves or their departments\nUse Employee Engagement Metrics to find out if there are better process your team ...

# %%
def summarize(url):
    website = Website(url)
    messages = [
    {"role":"system","content":"You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."},
    {"role":"user", "content":user_prompt_for(website)}
]
    response = ollama.chat(model=MODEL, messages=messages)
    return response['message']['content']

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))


display_summary("https://udemy.com")
