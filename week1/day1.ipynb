# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## Your first Frontier LLM Project
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### If necessary, install Cursor Extensions
#
# 1. From the View menu, select Extensions
# 2. Search for Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. Search for Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install of not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI (or Ollama)
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# If you'd like to use free Ollama instead, please see the README section "Free Alternative to Paid APIs", and if you're not sure how to do this, there's a full solution in the solutions folder (day1_with_ollama.ipynb).
#
# ## Troubleshooting if you have problems:
#
# If you get a "Name Error" - have you run all cells from the top down? Head over to the Python Foundations guide for a bulletproof way to find and fix all Name Errors.
#
# If that doesn't fix it, head over to the [troubleshooting](../setup/troubleshooting.ipynb) notebook for step by step code to identify the root cause and fix it!
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# Hello and welcome! I'm glad to hear from you. How can I assist you today?

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content

# %% [markdown]
# ## OK onwards with our first project

# %%
# Let's try out this utility

ed = Website("https://edwarddonner.com")
print(ed)
# Out:
# Cloud 9 Computing Group - Enterprise IT Services and Cloud Migration for Small Business
# top of page
# Service Status
# Live Support
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# More
# Use tab to navigate through the menu items.
# We believe
# Standardization
# brings
# focus to Process
# Optimization
# which enables businesses to
# scale
# EXISTING CUSTOMER SUPPORT
# INQUIRE ABOUT OUR SERVICES
# What is Hybrid Cloud?
# We are a
# Managed Service Provider
# with Process and Operations Strategy in Mind
# CLOUD SERVICES
# Optimize application usability and monitor performance with scalable solutions tailored to your needs. We help you enhance uptime, boost efficiency, track employee productivity, and potentially reduce costs, ensuring you only invest in the managed IT services that benefit you most.
# NETWORK SECURITY
# We utilize the same technology as leading Incident Response Firms. Our network security stack aligns with insurer requirements for cybersecurity, aiding in passing SOC and other compliance assessments. Our tools and SOC detect intrusions and help prevent unauthorized access to your systems.
# IT SUPPORT
# Simplify your operations with our comprehensive solutions, including proven processes, ticketing portals, policy templates, experienced helpdesk staff, and shared documentation—all from a single source. We also ensure that your incident response plans align with your business objectives.
# Key Benefits of Our Approach
# SIMPLIFIED TECHNOLOGY, 24/7 ACCESSIBILITY
# Host all of your company’s software, data, and tools in proven environments, making data accessible and secure wherever and whenever you need it.
# INCREASED EFFICIENCY
# Optimize your business’s efficiency by reducing downtime and technical risks by using best in class security tools and practices, redundant systems, and backup recovery tools that meet your objectives.  Use metrics collected on workstations to assess work from home network quality and user productivity.
# INTEGRATED SOLUTIONS
# After examining your biggest pain points, we custom tailor ticketing portals to get personnel results as quickly as possible by asking the right questions at the time a ticket is submitted.
# ​
# We constantly review and refine our processes along with your organization
# CONTROLLABLE MONTHLY COSTS
# Standardizing your IT means standardized pricing, based on the options that fit your company.
# Our pricing model is based on number of users, servers, email accounts, and what level of backup recovery you want available.
# ZERO DOWN-TIME OPTIONS
# If a computer or device quits, your team can continue working from another device without missing a beat.
# We also have specialized server offerings that can withstand catastrophic failure.
# SECURITY MATURE
# Our Security Solutions engage experienced Digital Forensics and Incident Response (DFIR) firms on your behalf, so you can rest assured you'll have best-in-class security and detection that meets compliance requirements and Cyber Liability Audits
# SEE HOW OUR STRATEGIC IT SOLUTIONS CAN BENEFIT YOUR ORGANIZATION
# LEARN MORE
# Key Benefits
# Why We're Different
# Operations Focused Strategic Solutions vs Reactive Approach
# STRATEGIC SOLUTIONS
# TRADITIONAL REACTIVE APPROACH
# Aware of YOUR business goals. Putting roadmaps for operations and technology together.
# Focus on just running the computers and network.
# Constantly refining processes from IT Support, Employees, and Customer feedback
# No Centralized notes for Technicians to follow for the repeated issues and processes
# Established Technology Policies and Employee Security Training out of the box
# Staff has to guess on policies for themselves or their departments
# Use Employee Engagement Metrics to find out if there are better process your team could be doing.  Learn from your own rock stars.
# No Structured Plans for Offboarded Employees, Hardware Budget Reviews, and upcoming projects.  Things only happen as they are needed.
# Rely only on built-in security products that have multiple places to log into for identity validation and can be difficult to setup on mobile devices
# Use Scalable Security Products that can grow with your business across multiple platforms
# Customized Customer Portal with common questions and solutions catered to your staff
# One Size Fits All Ticketing Systems where you can "just email"
# FIND OUT IF YOUR
# IT SUPPORT
# IS
# STRATEGICALLY FOCUSED
# ON
# YOUR BUSINESS
# START NOW
# Why We're Different
# Who We Help
# Custom strategic solutions tailored for your industry
# We provide best practice customized solutions fit to tackle your business's unique needs and concerns
# CONSTRUCTION
# Boost your team's speed and efficiency by making essential files—such as plans, schedules, and project management tools—accessible from anywhere, on any device. Whether you're a specialty contractor or an architecture and engineering firm, we understand your daily tools and deploy them securely and efficiently.
# MANUFACTURING
# With the rise of CIS Frameworks translating into NIST 800-171 compliance, it's crucial to secure manufacturing facilities that often use older machinery. We employ network segmentation, auditing, and innovative solutions to maintain security and functionality.
# ​
# FINANCIAL / LEGAL
# Protect your firm's
# and
# your client's private information by centralizing security, access, and backups where needed. Whether you're in the demanding fast-paced nature of the Legal, Finance or Accounting services.​ We understand SOC Audits, Security Frameworks, Archival Regulations and Compliance.
# BUILD YOUR CUSTOMIZED STRATEGIC PLAN
# GET STARTED
# Who We Help
# What It Costs
# How we work with your budget and team
# At Cloud 9 Computing Group, we offer transparent and flexible pricing structures tailored to your business’s specific needs. Our pricing model is designed to accommodate the unique requirements of your company, factoring in the number of employees, servers, and email accounts. All while ensuring you receive the highest quality of managed IT services and cloud solutions.
# Our solutions are catered to you based on your need.
# Get Your Quote
# What It Costs
# Brands Who Trust Us
# Cloud 9 offers solutions that are right sized for our business – cost effective and yet cutting edge. They have helped us with everything from computer purchases, installs and management, to entire IT infrastructure changes, VOIP phone system implementation, state of the art wireless (WiFi) technology, and cloud servers for software and documents.
# Cloud 9 does it all and they are the best IT partner you could have!
# Pam Russell, Director of Finance and Administration,
# La-Z-Boy Furniture Galleries Orlando
# Our Tech Partners
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# 917 RINEHART RD, SUITE 2027, LAKE MARY, FL 32746
# 877.454.1649
# Refreshed in ©2020 All Rights Reserved.
# Cloud
# bottom of page

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarkyassistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
print(user_prompt_for(ed))
# Out:
# You are looking at a website titled Cloud 9 Computing Group - Enterprise IT Services and Cloud Migration for Small Business
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# top of page
# Service Status
# Live Support
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# More
# Use tab to navigate through the menu items.
# We believe
# Standardization
# brings
# focus to Process
# Optimization
# which enables businesses to
# scale
# EXISTING CUSTOMER SUPPORT
# INQUIRE ABOUT OUR SERVICES
# What is Hybrid Cloud?
# We are a
# Managed Service Provider
# with Process and Operations Strategy in Mind
# CLOUD SERVICES
# Optimize application usability and monitor performance with scalable solutions tailored to your needs. We help you enhance uptime, boost efficiency, track employee productivity, and potentially reduce costs, ensuring you only invest in the managed IT services that benefit you most.
# NETWORK SECURITY
# We utilize the same technology as leading Incident Response Firms. Our network security stack aligns with insurer requirements for cybersecurity, aiding in passing SOC and other compliance assessments. Our tools and SOC detect intrusions and help prevent unauthorized access to your systems.
# IT SUPPORT
# Simplify your operations with our comprehensive solutions, including proven processes, ticketing portals, policy templates, experienced helpdesk staff, and shared documentation—all from a single source. We also ensure that your incident response plans align with your business objectives.
# Key Benefits of Our Approach
# SIMPLIFIED TECHNOLOGY, 24/7 ACCESSIBILITY
# Host all of your company’s software, data, and tools in proven environments, making data accessible and secure wherever and whenever you need it.
# INCREASED EFFICIENCY
# Optimize your business’s efficiency by reducing downtime and technical risks by using best in class security tools and practices, redundant systems, and backup recovery tools that meet your objectives.  Use metrics collected on workstations to assess work from home network quality and user productivity.
# INTEGRATED SOLUTIONS
# After examining your biggest pain points, we custom tailor ticketing portals to get personnel results as quickly as possible by asking the right questions at the time a ticket is submitted.
# ​
# We constantly review and refine our processes along with your organization
# CONTROLLABLE MONTHLY COSTS
# Standardizing your IT means standardized pricing, based on the options that fit your company.
# Our pricing model is based on number of users, servers, email accounts, and what level of backup recovery you want available.
# ZERO DOWN-TIME OPTIONS
# If a computer or device quits, your team can continue working from another device without missing a beat.
# We also have specialized server offerings that can withstand catastrophic failure.
# SECURITY MATURE
# Our Security Solutions engage experienced Digital Forensics and Incident Response (DFIR) firms on your behalf, so you can rest assured you'll have best-in-class security and detection that meets compliance requirements and Cyber Liability Audits
# SEE HOW OUR STRATEGIC IT SOLUTIONS CAN BENEFIT YOUR ORGANIZATION
# LEARN MORE
# Key Benefits
# Why We're Different
# Operations Focused Strategic Solutions vs Reactive Approach
# STRATEGIC SOLUTIONS
# TRADITIONAL REACTIVE APPROACH
# Aware of YOUR business goals. Putting roadmaps for operations and technology together.
# Focus on just running the computers and network.
# Constantly refining processes from IT Support, Employees, and Customer feedback
# No Centralized notes for Technicians to follow for the repeated issues and processes
# Established Technology Policies and Employee Security Training out of the box
# Staff has to guess on policies for themselves or their departments
# Use Employee Engagement Metrics to find out if there are better process your team could be doing.  Learn from your own rock stars.
# No Structured Plans for Offboarded Employees, Hardware Budget Reviews, and upcoming projects.  Things only happen as they are needed.
# Rely only on built-in security products that have multiple places to log into for identity validation and can be difficult to setup on mobile devices
# Use Scalable Security Products that can grow with your business across multiple platforms
# Customized Customer Portal with common questions and solutions catered to your staff
# One Size Fits All Ticketing Systems where you can "just email"
# FIND OUT IF YOUR
# IT SUPPORT
# IS
# STRATEGICALLY FOCUSED
# ON
# YOUR BUSINESS
# START NOW
# Why We're Different
# Who We Help
# Custom strategic solutions tailored for your industry
# We provide best practice customized solutions fit to tackle your business's unique needs and concerns
# CONSTRUCTION
# Boost your team's speed and efficiency by making essential files—such as plans, schedules, and project management tools—accessible from anywhere, on any device. Whether you're a specialty contractor or an architecture and engineering firm, we understand your daily tools and deploy them securely and efficiently.
# MANUFACTURING
# With the rise of CIS Frameworks translating into NIST 800-171 compliance, it's crucial to secure manufacturing facilities that often use older machinery. We employ network segmentation, auditing, and innovative solutions to maintain security and functionality.
# ​
# FINANCIAL / LEGAL
# Protect your firm's
# and
# your client's private information by centralizing security, access, and backups where needed. Whether you're in the demanding fast-paced nature of the Legal, Finance or Accounting services.​ We understand SOC Audits, Security Frameworks, Archival Regulations and Compliance.
# BUILD YOUR CUSTOMIZED STRATEGIC PLAN
# GET STARTED
# Who We Help
# What It Costs
# How we work with your budget and team
# At Cloud 9 Computing Group, we offer transparent and flexible pricing structures tailored to your business’s specific needs. Our pricing model is designed to accommodate the unique requirements of your company, factoring in the number of employees, servers, and email accounts. All while ensuring you receive the highest quality of managed IT services and cloud solutions.
# Our solutions are catered to you based on your need.
# Get Your Quote
# What It Costs
# Brands Who Trust Us
# Cloud 9 offers solutions that are right sized for our business – cost effective and yet cutting edge. They have helped us with everything from computer purchases, installs and management, to entire IT infrastructure changes, VOIP phone system implementation, state of the art wireless (WiFi) technology, and cloud servers for software and documents.
# Cloud 9 does it all and they are the best IT partner you could have!
# Pam Russell, Director of Finance and Administration,
# La-Z-Boy Furniture Galleries Orlando
# Our Tech Partners
# SERVICES
# KEY BENEFITS
# WHY WE'RE DIFFERENT
# WHO WE HELP
# WHAT IT COSTS
# NEWS
# 917 RINEHART RD, SUITE 2027, LAKE MARY, FL 32746
# 877.454.1649
# Refreshed in ©2020 All Rights Reserved.
# Cloud
# bottom of page

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content

# %%
# To give you a preview -- calling OpenAI with system and user messages:

response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# Oh, you really want to dive into the deep end of mathematics, huh? Well, hold onto your hat, because 2 + 2 equals 4. Mind-blowing, I know!

# %% [markdown]
# ## And now let's build useful messages for GPT-4.1-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': 'You are looking at a website titled Cloud 9 Computing Group - Enterprise IT Services and Cloud Migration for Small Business\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\ntop of page\nService Status\nLive Support\nSERVICES\nKEY BENEFITS\nWHY WE\'RE DIFFERENT\nWHO WE HELP\nWHAT IT COSTS\nNEWS\nMore\nUse tab to navigate through the menu items.\nWe believe\nStandardization\nbrings\nfocus to Process\nOptimization\nwhich enables businesses to\nscale\nEXISTING CUSTOMER SUPPORT\nINQUIRE ABOUT OUR SERVICES\nWhat is Hybrid Cloud?\nWe are a\nManaged Service Provider\nwith Process and Operations Strategy in Mind\nCLOUD SERVICES\nOptimize application usability and monitor performance with scalable solutions tailored to your needs. We help you enhance uptime, boost efficiency, track employee productivity, and potentially reduce costs, ensuring you only invest in the managed IT services that benefit you most.\nNETWORK SECURITY\nWe utilize the same technology as leading Incident Response Firms. Our network security stack aligns with insurer requirements for cybersecurity, aiding in passing SOC and other compliance assessments. Our tools and SOC detect intrusions and help prevent unauthorized access to your systems.\nIT SUPPORT\nSimplify your operations with our comprehensive solutions, including proven processes, ticketing portals, policy templates, experienced helpdesk staff, and shared documentation—all from a single source. We also ensure that your incident response plans align with your business objectives.\nKey Benefits of Our Approach\nSIMPLIFIED TECHNOLOGY, 24/7 ACCESSIBILITY\nHost all of your company’s software, data, and tools in proven environments, making data accessible and secure wherever and whenever you need it.\nINCREASED EFFICIENCY\nOptimize your business’s efficiency by reducing downtime and technical risks by using best in class security tools and practices, redundant systems, and backup recovery tools that meet your objectives.\xa0 Use metrics collected on workstations to assess work from home network quality and user productivity.\nINTEGRATED SOLUTIONS\nAfter examining your biggest pain points, we custom tailor ticketing portals to get personnel results as quickly as possible by asking the right questions at the time a ticket is submitted.\n\u200b\nWe constantly review and refine our processes along with your organization\nCONTROLLABLE MONTHLY COSTS\nStandardizing your IT means standardized pricing, based on the options that fit your company.\nOur pricing model is based on number of users, servers, email accounts, and what level of backup recovery you want available.\nZERO DOWN-TIME OPTIONS\nIf a computer or device quits, your team can continue working from another device without missing a beat.\nWe also have specialized server offerings that can withstand catastrophic failure.\nSECURITY MATURE\nOur Security Solutions engage experienced Digital Forensics and Incident Response (DFIR) firms on your behalf, so you can rest assured you\'ll have best-in-class security and detection that meets compliance requirements and Cyber Liability Audits\nSEE HOW OUR STRATEGIC IT SOLUTIONS CAN BENEFIT YOUR ORGANIZATION\nLEARN MORE\nKey Benefits\nWhy We\'re Different\nOperations Focused Strategic Solutions vs Reactive Approach\nSTRATEGIC SOLUTIONS\nTRADITIONAL REACTIVE APPROACH\nAware of YOUR business goals. Putting roadmaps for operations and technology together.\nFocus on just running the computers and network.\nConstantly refining processes from IT Support, Employees, and Customer feedback\nNo Centralized notes for Technicians to follow for the repeated issues and processes\nEstablished Technology Policies and Employee Security Training out of the box\nStaff has to guess on policies for themselves or their departments\nUse Employee Engagement Metrics to find out if there are better process your team ...

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://cloud9computinggroup.com")
# Out:
# "# Cloud 9 Computing Group - Summary\n\nCloud 9 Computing Group provides enterprise IT services focused on cloud migration for small businesses. As a Managed Service Provider (MSP), they emphasize process optimization and standardized solutions to improve scalability and efficiency for their clients. \n\n## Key Offerings\n\n- **Cloud Services**: Tailored cloud solutions that enhance application usability, uptime, and efficiency while monitoring performance and reducing costs.\n  \n- **Network Security**: Comprehensive cybersecurity measures in compliance with insurance requirements, leveraging cutting-edge tools and strategies to prevent unauthorized access.\n  \n- **IT Support**: A centralized support system that streamlines operations, includes a ticketing portal, and provides resources for incident response aligned with business goals.\n\n## Benefits of Their Approach\n\n- **Simplified Technology**: Provides accessible and secure software and data solutions.\n- **Increased Efficiency**: Reduces downtime and technical risks with security practices and backup systems.\n- **Custom Solutions**: Tailored ticketing portals to enhance team responsiveness and streamline user experience.\n- **Controllable Costs**: Transparent pricing based on usage metrics specific to clients' needs.\n\n## Target Industries\n\nCloud 9 specializes in tailored solutions for various sectors including:\n- **Construction**: Enhances access to essential project files from any device.\n- **Manufacturing**: Focuses on security for older machinery while maintaining functionality and compliance.\n- **Financial & Legal**: Centralizes security and compliance needs for sensitive information management.\n\n## Pricing\n\nCloud 9 offers flexible pricing models based on individual client needs, accommodating aspects like the number of employees and servers while ensuring quality service delivery.\n\n## Client Testimonials\n\nFeedback from clients highlights Cloud 9's effectiveness in delivering cost-effective, cutting-edge IT solutions across various operational needs, cementing their reputation as a reliable IT partner.\n\n---\n\nFor more detailed insights into strategy and specific service offerings, users are encouraged to explore their website directly."

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://cloud9computinggroup.com")
# Out:
# # Cloud 9 Computing Group - Summary
#
# Cloud 9 Computing Group specializes in providing **enterprise IT services** and **cloud migration solutions** tailored for small businesses. They offer a variety of services designed to optimize business processes, enhance network security, and improve overall efficiency while ensuring scalability and compliance.
#
# ## Key Services
#
# - **Cloud Services**: Custom solutions to optimize application usability and monitor performance, aimed at enhancing uptime and reducing costs.
#
# - **Network Security**: Advanced security measures aligned with incident response standards, ensuring compliance with cybersecurity requirements.
#
# - **IT Support**: Comprehensive support solutions including ticketing portals, helpdesk assistance, and documentation tailored to meet business objectives.
#
# ## Key Benefits
#
# - **Simplified Technology**: Accessible and secure software and data hosting.
# - **Increased Efficiency**: Reduction in downtime and technical risks using best-in-class security tools.
# - **Integrated Solutions**: Custom ticketing portals to address specific organizational pain points.
# - **Controllable Monthly Costs**: Transparent pricing models based on user and system needs.
# - **Zero Downtime Options**: Specialized server offerings to ensure business continuity.
#
# ## Unique Approach
#
# Cloud 9 Computing differentiates itself by focusing on **strategic solutions** rather than **reactive approaches**. They emphasize tailored plans based on business goals, regular process refinement, and proactive security measures.
#
# ## Target Industries
#
# - **Construction**: Providing secure access to essential project management tools.
# - **Manufacturing**: Ensuring security compliance while maintaining functionality.
# - **Financial/Legal**: Centralizing security and backups to protect sensitive information.
#
# ## Pricing Structure
#
# The company offers **flexible pricing** that accommodates various business needs, factoring in the number of employees, servers, and specific service requirements.
#
# ## Client Testimonials
#
# One client emphasized that Cloud 9 provides cost-effective and cutting-edge solutions for everything from IT management to infrastructure changes.
#
# ## News
#
# No specific news or announcements were found on the site.
#
# For further information or to inquire about their services, Cloud 9 Computing Group encourages potential clients to get in touch directly.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://jacobsonphillips.com")
# Out:
# # Jacobson Phillips PLLC Website Summary
#
# Jacobson Phillips PLLC is a law firm specialized in class action and appellate litigation. Their focus is on representing individuals in class action cases against corporations for various legal issues, including:
#
# - Data Breach
# - Financial Mismanagement
# - Insurance Total Loss
# - Military Lending Act
# - TCPA (Telephone Consumer Protection Act)
#
# ### Key Highlights
# - The firm has achieved significant settlements for clients, amounting to tens of millions of dollars in various class action lawsuits against auto insurance companies and other corporations.
# - Notable settlements include:
#   - **$33,700,000** for a Total Loss class action against an auto insurance company.
#   - **$8,950,000** in a TCPA class action against a multinational automaker.
#   - Multiple settlements exceeding $27 million against auto insurance companies.
#
# ### Contact Information
# - **Email:** info@jacobsonphillips.com
# - **Address:** 2277 Lee Road, Suite B, Winter Park, FL 32789
# - **Phone:** +1 (321) 447-6461
#
# The firm positions itself as advocates for individuals wronged by corporate practices, making a commitment to fight for justice through effective litigation.

# %%
display_summary("https://anthropic.com")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

system_prompt = "something here"
user_prompt = """
    Lots of text
    Can be pasted here
"""

# Step 2: Make the messages list

messages = [] # fill this in

# Step 3: Call OpenAI
# response =

# Step 4: print the result
# print(

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then GPT has given some nice instructions on how to submit a Pull Request. It's a bit of an involved process, but once you've done it once it's pretty clear. As a pro-tip: it's best if you clear the outputs of your Jupyter notebooks (Edit >> Clean outputs of all cells, and then Save) for clean notebooks.
#
# Here are good instructions courtesy of an AI friend:
# https://chatgpt.com/share/677a9cb5-c64c-8012-99e0-e06e88afd293
